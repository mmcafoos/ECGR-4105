# %%
#Name: Mark McAfoose
#Student ID: 801149826
#Homework 0
#Github Link
#

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#To be honest, I didn't quite understand what all the question was asking, so there may
#be stuff from the linear regression example that the question doesn't need
#If it looks heavily plagirized from the example that's because it is
#Also I enjoy using different colors for my graph

df = pd.read_csv('C:/Users/mcafo/Desktop/D3.csv')
#Tried putting file into its own separate folder, but for some reason it would not read it
df.head() # To get first n rows from the dataset default value of n is 5
M=len(df)
M
#For some reason, it wouldn't take from the 1st row of the excel file. Not quite sure why
# Out:
# 99

# %%
#Problem 1, take example code and make it work for 3 different variables
X1 = df.values[:, 0] # get input values from first column
X2 = df.values[:, 1] # get input values from second column
X3 = df.values[:, 2] # get input values from third column
y = df.values[:, 3] # get output values from fourth column
m = len(y) # Number of training examples
print('X1 = ', X1[: 5]) # Show only first 5 records
print('X2 = ', X2[: 5]) # Show only first 5 records
print('X3 = ', X3[: 5]) # Show only first 5 records
print('y = ', y[: 5])
print('m = ', m)
X1 = df.values[:, 0] # get input values from first column
X2 = df.values[:, 1] # get input values from second column
X3 = df.values[:, 2] # get input values from third column
y = df.values[:, 3] # get output values from fourth column
m = len(y) # Number of training examples
print('X1 = ', X1[: 97]) #Chose 97 as training example had it
print('X2 = ', X2[: 97]) 
print('X3 = ', X3[: 97])
print('y = ', y[: 97])
print('m = ', m)
# Out:
# X1 =  [0.04040404 0.08080808 0.12121212 0.16161616 0.2020202 ]
# X2 =  [0.13494949 0.82989899 1.52484848 2.21979798 2.91474747]
# X3 =  [0.88848485 1.3369697  1.78545455 2.23393939 2.68242424]
# y =  [2.6796499  2.96848981 3.25406475 3.53637472 3.81541972]
# m =  99
# X1 =  [0.04040404 0.08080808 0.12121212 0.16161616 0.2020202  0.24242424
#  0.28282828 0.32323232 0.36363636 0.4040404  0.44444444 0.48484848
#  0.52525253 0.56565657 0.60606061 0.64646465 0.68686869 0.72727273
#  0.76767677 0.80808081 0.84848485 0.88888889 0.92929293 0.96969697
#  1.01010101 1.05050505 1.09090909 1.13131313 1.17171717 1.21212121
#  1.25252525 1.29292929 1.33333333 1.37373737 1.41414141 1.45454545
#  1.49494949 1.53535354 1.57575758 1.61616162 1.65656566 1.6969697
#  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899  1.93939394
#  1.97979798 2.02020202 2.06060606 2.1010101  2.14141414 2.18181818
#  2.22222222 2.26262626 2.3030303  2.34343434 2.38383838 2.42424242
# ...

# %%
#Plotting Scatter Graph For X1
plt.scatter(X1,y,color='red',marker='+')
plt.grid()
plt.title('Scatter Plot of Training Data for X1')
plt.rcParams["figure.figsize"]=(10,6)
#Tried changing figure in code above, but no number changed anything, so went back to 10 6
plt.xlabel('Independant Variable from X1')
plt.ylabel('Dependant Variable ')
# Out:
# Text(0, 0.5, 'Dependant Variable ')

# %%
#Plotting Scatter Graph For X2
plt.scatter(X2,y,color='blue',marker='+')
plt.grid()
plt.title('Scatter Plot of Training Data for X2')
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable from X2')
plt.ylabel('Dependant Variable')
# Out:
# Text(0, 0.5, 'Dependant Variable')

# %%
#Plotting Scatter Graph For X3
plt.scatter(X3,y,color='green',marker='+')
plt.grid()
plt.title('Scatter Plot for Training Data in X3')
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable X3')
plt.ylabel('Dependant Variable')
# Out:
# Text(0, 0.5, 'Dependant Variable')

# %%
#Still don't quite understand arrays that well, taken from example
p = np.ones((m,1))
p[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X1 = X1.reshape(m,1)
X2= X2.reshape(m,1)
X3 = X3.reshape(m,1)

# %%
#Linear Regression / Gradient Decent for X1
X=np.hstack((p,X1))

# %%
#Not sure why in different kernel, just following example
theta=np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
def compute_cost(X,y,theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions,y)
    sqrErrors=np.square(errors)
    J = 1/(2*m)*np.sum(sqrErrors)
    return J
cost=compute_cost(X,y,theta)
print('The cost for given values of theta_0 and theta_1 =',cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.483015861682611

# %%
def gradient_descent(X, y, theta, alpha, iterations): #Gradient decent for first column
    cost_history=np.zeros(iterations)
    for i in range(iterations):
        prediction = X.dot(theta)
        errors = np.subtract(prediction,y)
        sum_delta = (alpha/m)*X.transpose().dot(errors);
        theta=theta-sum_delta;
        cost_history[i]=compute_cost(X,y,theta)
    
    return theta,cost_history
theta = [0.,0.]
iterations = 1500;
alpha = 0.01;   
theta, cost_history = gradient_descent(X,y,theta,alpha,iterations)
print('Final value of theta =',theta)
print('cost_history =',cost_history) 
#The example had these split into different kernels, but I felt merging was the best option
# Out:
# Final value of theta = [ 5.75752967 -1.97114532]
# cost_history = [5.4416155  5.40304386 5.36697031 ... 0.98927932 0.98925005 0.98922091]

# %%
plt.scatter(X[:,1],y,color='gold',marker='+',label='Training Data')
plt.plot(X[:,1],X.dot(theta),color='green',label='Linear Regression')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X1')
# Out:
# Text(0.5, 1.0, 'Linear Regression for X1')

# %%
#Gradient Descent. Wasn't sure whether to put this in same graph as linear regression
plt.plot(range(1,iterations+1),cost_history,color='green')
plt.rcParams["figure.figsize"]=(10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for X1')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for X1')

# %%
#Linear Regression / Gradient Decent for X2
X=np.hstack((p,X2))
theta=np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
#Essentially just doing the same thing, but based on x2 now
def compute_cost(X,y,theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions,y)
    sqrErrors=np.square(errors)
    J = 1/(2*m)*np.sum(sqrErrors)
    return J
cost=compute_cost(X,y,theta)
print('The cost for given values of theta_0 and theta_1 =',cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.483015861682611

# %%
def gradient_descent(X, y, theta, alpha, iterations):
    cost_history=np.zeros(iterations)
    for i in range(iterations):
        prediction = X.dot(theta)
        errors = np.subtract(prediction,y)
        sum_delta = (alpha/m)*X.transpose().dot(errors);
        theta=theta-sum_delta;
        cost_history[i]=compute_cost(X,y,theta)
    
    return theta,cost_history
theta = [0.,0.]
iterations = 1500;
alpha = 0.01; 
theta, cost_history = gradient_descent(X,y,theta,alpha,iterations)
print('Final value of theta =',theta)
print('cost_history =',cost_history) 
#Didn't feel the need to split kernels here, since they essentially share the same output
# Out:
# Final value of theta = [0.7392744 0.5453018]
# cost_history = [5.2669085  5.07623409 4.90799786 ... 3.6201926  3.62019244 3.62019228]

# %%
plt.scatter(X[:,1],y,color='purple',marker='+',label='Training Data')
plt.plot(X[:,1],X.dot(theta),color='green',label='Linear Regression')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression For X2')
# Out:
# Text(0.5, 1.0, 'Linear Regression For X2')

# %%
#Gradient Descent into madness
plt.plot(range(1,iterations+1),cost_history,color='blue')
plt.rcParams["figure.figsize"]=(10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for X2')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for X2')

# %%
#Linear Regression and Gradient Descent for X3
X=np.hstack((p,X3))
theta=np.zeros(2)
theta
# Out:
# array([0., 0.])

# %%
  def compute_cost(X,y,theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions,y)
    sqrErrors=np.square(errors)
    J = 1/(2*m)*np.sum(sqrErrors)
    return J
cost=compute_cost(X,y,theta)
print('The cost for given values of theta_0 and theta_1 =',cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.483015861682611

# %%
def gradient_descent(X, y, theta, alpha, iterations):
    cost_history=np.zeros(iterations)
    for i in range(iterations):
        prediction = X.dot(theta)
        errors = np.subtract(prediction,y)
        sum_delta = (alpha/m)*X.transpose().dot(errors);
        theta=theta-sum_delta;
        cost_history[i]=compute_cost(X,y,theta)
    
    return theta,cost_history
theta = [0.,0.]
iterations = 1500;
alpha = 0.01;
theta, cost_history = gradient_descent(X,y,theta,alpha,iterations)
print('Final value of theta =',theta)
print('cost_history =',cost_history)
# Out:
# Final value of theta = [ 2.71943299 -0.46300206]
# cost_history = [5.366643   5.26340773 5.17178032 ... 3.65144217 3.65143712 3.6514321 ]

# %%
plt.scatter(X[:,1],y,color='mediumvioletred',marker='+',label='Training Data')
#Got distracted and looked up python colors
plt.plot(X[:,1],X.dot(theta),color='green',label='Linear Regression')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X3')
# Out:
# Text(0.5, 1.0, 'Linear Regression for X3')

# %%
#Gradient Descent
plt.plot(range(1,iterations+1),cost_history,color='firebrick')
plt.rcParams["figure.figsize"]=(10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for X3 and my Sanity')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for X3 and my Sanity')

# %%
#Code for Problem 1 is all above, below is the questions for it

# %%
#Problem 1 Question 1
#I am assuming that reporting the linear model you found for each explantory variable is
#Answered by the graphs above

#Problem 1 Question 2
#Once again, I am assuming that this question is answered by the graphs and numbers 
#Given Above

#Problem 1 Question 3
#Judging by the gradient descent slopes for each variable, X1 would have the lowest loss
#For explaining the output. X2 and X3 have a much sleeper slope than X1

#Problem 1 Question 4
#If the learning rate is too high,the cost function has a steep drop to the end of the function
#which means it only has a small amount of iterations when it reaches the end. 
#This means it's still stupid and has very little usable information

# %%
#Problem 2,take problem 1 and put it all on the same plot I think

# %%
#Putting all three variables into 1 array
X_Fusion= np.hstack((p,X1,X2,X3))
theta=np.zeros(4)
theta
# Out:
# array([0., 0., 0., 0.])

# %%
def compute_cost(X_Fusion,y,theta):
    predictions = X_Fusion.dot(theta)
    errors = np.subtract(predictions,y)
    sqrErrors=np.square(errors)
    J = 1/(2*m)*np.sum(sqrErrors)
    return J
cost=compute_cost(X_Fusion,y,theta)
print('The cost for given values of theta_0 and theta_1 =',cost)
# Out:
# The cost for given values of theta_0 and theta_1 = 5.483015861682611

# %%
def gradient_descent(X_Fusion, y, theta, alpha, iterations):
    cost_history=np.zeros(iterations)
    for i in range(iterations):
        prediction = X_Fusion.dot(theta)
        errors = np.subtract(prediction,y)
        sum_delta = (alpha/m)*X_Fusion.transpose().dot(errors);
        theta=theta-sum_delta;
        cost_history[i]=compute_cost(X_Fusion,y,theta)
    
    return theta,cost_history
theta = [0., 0., 0.,0.,]
iterations = 1500;
#Chose learning rate of 0.1 to spice it up
alpha = 0.1; 
theta, cost_history = gradient_descent(X_Fusion,y,theta,alpha,iterations)
print('Final value of theta =',theta)
print('cost_history =',cost_history)
# Out:
# Final value of theta = [ 5.41374693 -2.04203017  0.56122181 -0.2921286 ]
# cost_history = [4.1450758  3.54646843 3.16253942 ... 0.70818787 0.70818787 0.70818787]

# %%
#Da Final Linear Regression
plt.scatter(X_Fusion[:,1],y,color='red',marker='+',label='Training Data')
plt.plot(X_Fusion[:,1],X_Fusion.dot(theta),color='green',label='Linear Regression')
plt.grid()
plt.rcParams["figure.figsize"]=(10,6)
plt.xlabel('Independant Variable')
plt.ylabel('Dependant Variable')
plt.title('Linear Regression for X1, X2, and X3')
# Out:
# Text(0.5, 1.0, 'Linear Regression for X1, X2, and X3')

# %%
#Da Final Gradient Descent
plt.plot(range(1,iterations+1),cost_history,color='darkslategray')
plt.rcParams["figure.figsize"]=(10,6)
plt.grid()
plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Gradient Descent for X1, X2, and X3')
# Out:
# Text(0.5, 1.0, 'Gradient Descent for X1, X2, and X3')

# %%
#Code for Problem 2 is all above, below is the questions for it

# %%
#Problem 2 Question 1
#I am assuming this is answered by the graphs above

#Problem 2 Question 2
#Once again, I am assuming this is answered by the graphs above

#Problem 2 Question 3
#It would be same as in Problem 1 Question 3. Too high of a learning rate moves the cost
#function too far too fast.

#Problem 2 Question 4
#For values 1,1,1 y would be 2
#For values 2,0,4 y would be 1.5
#For values 3,2,1 y would 1
#Where did I get these values from? Not even I know.
